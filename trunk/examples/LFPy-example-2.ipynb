# %% [markdown]
# # Example 2: Extracellular response of synaptic input#First step is to **import LFPy** and other packages:

# %%
import LFPyfrom pylab import *

# %% [markdown]
# Create some dictionarys with parameters for cell, synapse and extracellular electrode:

# %%
cellParameters = {    'morphology' : 'morphologies/L5_Mainen96_LFPy.hoc',}synapseParameters = {    'syntype' : 'Exp2Syn',    'e' : 0.,    'tau1' : 0.5,    'tau2' : 2.0,    'weight' : 0.005,    'record_current' : True,}z = np.mgrid[-400:1201:100]electrodeParameters = {    'x' : zeros(z.size),    'y' : zeros(z.size),    'z' : z,    'sigma' : 0.3,}

# %% [markdown]
# Then, create the **cell**, **synapse** and **electrode** objects using **LFPy.Cell**, **LFPy.Synapse**, **LFPy.RecExtElectrode**.

# %%
cell = LFPy.Cell(**cellParameters)cell.set_pos(xpos=-10, ypos=0, zpos=0)synapse = LFPy.Synapse(cell,                       idx = cell.get_closest_idx(z=800),                       **synapseParameters)synapse.set_spike_times(array([10, 30, 50]))                        electrode = LFPy.RecExtElectrode(**electrodeParameters)

# %% [markdown]
# Run the simulation with **electrode** as input to **cell.simulate()**

# %%
cell.simulate(electrode = electrode, rec_isyn=True)
# Out:
# t = 10, realtime factor: 0.072t = 20, realtime factor: 0.078
# t = 30, realtime factor: 0.065
# t = 40, realtime factor: 0.065
# t = 50, realtime factor: 0.061
# t = 60, realtime factor: 0.061
# t = 70, realtime factor: 0.066
# t = 80, realtime factor: 0.054
# t = 90, realtime factor: 0.055
# t = 100, realtime factor: 0.057

# %% [markdown]
# Then plot the **somatic potential** and the **LFP**from electrode object:

# %%
figure(figsize=(12, 6))subplot(133)pcolormesh(cell.tvec, electrode.z, electrode.LFP,           vmin=-abs(electrode.LFP).max(), vmax=abs(electrode.LFP).max(),           cmap='spectral_r'), colorbar(), title('LFP (mV)')subplot(232)plot(cell.tvec, synapse.i), title('synaptic current (pA)')subplot(235)plot(cell.tvec, cell.somav), title('somatic voltage (mV)')subplot(131)for sec in LFPy.cell.neuron.h.allsec():    idx = cell.get_idx_section(sec.name())    plot(np.r_[cell.xstart[idx], cell.xend[idx][-1]],            np.r_[cell.zstart[idx], cell.zend[idx][-1]],            color='k')plot([cell.synapses[0].x], [cell.synapses[0].z], \     color=cell.synapses[0].color, marker=cell.synapses[0].marker, markersize=10)plot(electrode.x, electrode.z, '.', marker='o', color='g')axis([-500, 500, -400, 1200])savefig('LFPy-example-2.png', dpi=300)show()
