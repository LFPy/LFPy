# %% [markdown]
# # Example 1: Post-synaptic response of a single synapse #First step is to **import LFPy** and other packages:

# %%
import LFPyfrom pylab import *

# %% [markdown]
# Then, create the cell object using the **LFPy.Cell**-class, specifying the morphology file.The passive mechanismsare switched on by default.

# %%
cell = LFPy.Cell(morphology = 'morphologies/L5_Mainen96_LFPy.hoc')

# %% [markdown]
# One can now use **LFPy.Synapse**-class to insert a single synapse onto the soma compartment, and set the spike time(s) using **LFPy.Synapse.set_spike_times()**:

# %%
synapse = LFPy.Synapse(cell,                        idx = cell.get_idx_section("soma[0]"),                       syntype = 'Exp2Syn',                        weight = 0.005,                        e = 0,                        tau1 = 0.5,                       tau2 = 2,                       record_current = True)synapse.set_spike_times(array([20., 40]))

# %% [markdown]
# We now have what we need to calculate the postsynaptic response, without calculating LFPs,using a built in method **LFPy.Cell.simulate()** method to run the simulation.

# %%
cell.simulate(rec_isyn=True)
# Out:
# rec_imem = False, membrane currents will not be recorded!t = 10, realtime factor: 0.069
# t = 20, realtime factor: 0.113
# t = 30, realtime factor: 0.093
# t = 40, realtime factor: 0.044
# t = 50, realtime factor: 0.058
# t = 60, realtime factor: 0.062
# t = 70, realtime factor: 0.087
# t = 80, realtime factor: 0.086
# t = 90, realtime factor: 0.093
# t = 100, realtime factor: 0.117

# %% [markdown]
# Then plot the model geometry, synaptic current and somatic potential:

# %%
figure(figsize=(12, 9))subplot(222)plot(cell.tvec, synapse.i), title('synaptic current (pA)')subplot(224)plot(cell.tvec, cell.somav), title('somatic voltage (mV)')subplot(121)for sec in LFPy.cell.neuron.h.allsec():    idx = cell.get_idx_section(sec.name())    plot(np.r_[cell.xstart[idx], cell.xend[idx][-1]],            np.r_[cell.zstart[idx], cell.zend[idx][-1]],            color='k')plot([cell.synapses[0].x], [cell.synapses[0].z], \     color=cell.synapses[0].color, marker=cell.synapses[0].marker, markersize=10)axis([-500, 500, -400, 1200])#savefig('LFPy-example-1.png', dpi=200)show()
